# %% [markdown]
# ## Are They the Eyes of a Male or Female: Image Classification
#
# Dataset Source: https://www.kaggle.com/datasets/pavelbiz/eyes-rtte

# %% [markdown]
# ##### Install Necessary Libraries Not Already Installed

# %%
# %pip install datasets transformers tensorboard evaluate
# Out:
# Requirement already satisfied: datasets in ./nlp_ml/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: transformers in ./nlp_ml/lib/python3.9/site-packages (4.25.1)
# Requirement already satisfied: tensorboard in ./nlp_ml/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: evaluate in ./nlp_ml/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: pyyaml>=5.1 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (6.0)
# Requirement already satisfied: dill<0.3.7 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: aiohttp in ./nlp_ml/lib/python3.9/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: responses<0.19 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (9.0.0)
# Requirement already satisfied: xxhash in ./nlp_ml/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: packaging in ./nlp_ml/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: tqdm>=4.62.1 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (0.10.0)
# Requirement already satisfied: numpy>=1.17 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (1.23.3)
# Requirement already satisfied: requests>=2.19.0 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: multiprocess in ./nlp_ml/lib/python3.9/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: pandas in ./nlp_ml/lib/python3.9/site-packages (from datasets) (1.5.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in ./nlp_ml/lib/python3.9/site-packages (from datasets) (2022.8.2)
# Requirement already satisfied: regex!=2019.12.17 in ./nlp_ml/lib/python3.9/site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: filelock in ./nlp_ml/lib/python3.9/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./nlp_ml/lib/python3.9/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (58.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: protobuf<4,>=3.9.2 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (2.15.0)
# Requirement already satisfied: grpcio>=1.24.3 in ./nlp_ml/lib/python3.9/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./nlp_ml/lib/python3.9/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: six>=1.9.0 in ./nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./nlp_ml/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./nlp_ml/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./nlp_ml/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard) (5.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./nlp_ml/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./nlp_ml/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in ./nlp_ml/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./nlp_ml/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./nlp_ml/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./nlp_ml/lib/python3.9/site-packages (from pandas->datasets) (2022.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./nlp_ml/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in ./nlp_ml/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./nlp_ml/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./nlp_ml/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Import Necessary Libraries

# %%
import os, sys, random
os.environ['TOKENIZERS_PARALLELISM']='false'

from PIL import ImageDraw, ImageFont, Image
import PIL.Image

from tqdm import tqdm

import numpy as np
import pandas as pd

import datasets
from datasets import load_dataset, Image, load_metric, DatasetDict

import transformers
from transformers import Trainer, TrainingArguments
from transformers import ViTForImageClassification, ViTFeatureExtractor

import torch

import evaluate

# %% [markdown]
# ##### Display Versions of Relevant Libraries

# %%
print("Python:".rjust(15), sys.version[0:6])
print("NumPy:".rjust(15), np.__version__)
print("Pandas:".rjust(15), pd.__version__)
print("Datasets:".rjust(15), datasets.__version__)
print("Transformers:".rjust(15), transformers.__version__)
print("Torch:".rjust(15), torch.__version__)
# Out:
#         Python: 3.9.12
#          NumPy: 1.23.3
#         Pandas: 1.5.0
#       Datasets: 2.8.0
#   Transformers: 4.25.1
#          Torch: 1.12.1

# %% [markdown]
# ##### Ingest Dataset

# %%
dataset = load_dataset("imagefolder", 
                        data_dir="/Users/briandunn/Desktop/Vit Image Datasets/Female and Male Eyes", 
                        split='train',
                        drop_labels=False)
# Out:
# A Jupyter Widget
# Using custom data configuration default-34be8ec909709a38
# Found cached dataset imagefolder (/Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)

# %% [markdown]
# ##### Split Dataset into Training & Testing Datasets

# %%
dataset = dataset.shuffle(seed=42)

train_test = dataset.train_test_split(test_size=0.20)

train_ds, test_ds = train_test["train"], train_test["test"]

ds = DatasetDict({
    'train' : train_ds,
    'test' : test_ds
})

print(type(ds['train']))
print(type(ds['test']))
# Out:
# Loading cached shuffled indices for dataset at /Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f/cache-607454b6e2bdc204.arrow
# <class 'datasets.arrow_dataset.Dataset'>
# <class 'datasets.arrow_dataset.Dataset'>

# %% [markdown]
# ##### Some Information About Train & Test Datasets

# %%
print("Training Dataset")
print(ds['train'])
print(ds['train'][0])
print(ds['train'][-1])
print(sorted(ds['train'].unique("label")))

print("Testing Dataset")
print(ds['test'])
print(ds['test'][0])
print(ds['test'][-1])
print(sorted(ds['test'].unique("label")))
# Out:
# Training Dataset
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 9220
# })
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=48x48 at 0x7FC7E89545E0>, 'label': 0}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=61x61 at 0x7FC7E9A94C70>, 'label': 0}
# A Jupyter Widget
# [0, 1]
# Testing Dataset
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 2305
# })
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=55x55 at 0x7FC7E9A94310>, 'label': 1}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x60 at 0x7FC7E9A94220>, 'label': 0}
# A Jupyter Widget
# [0, 1]

# %% [markdown]
# ##### Display Grid of Examples From Each Class to Gain Better Picture of Data

# %%
def show_grid_of_examples(ds, 
                          seed: int = 42, 
                          examples_per_class: int = 3, 
                          size=(350, 350)):
    '''
    This function displays a few pictures
    from each class in the dataset.
    '''
    w, h = size
    labels = ds.features['label'].names
    grid = PIL.Image.new(mode='RGB', size=(examples_per_class * w, len(labels) * h))
    draw = ImageDraw.Draw(grid)
    font = ImageFont.truetype("Chalkduster.ttf", 24)
    
    for label_id, label in enumerate(labels):
        # filter the dataset by a single label, shuffle it, then grab a few samples
        ds_slice = ds \
                    .filter(lambda ex: ex['label'] == label_id) \
                    .shuffle(seed) \
                    .select(range(examples_per_class))
        
        # plot this label's examples in a row
        for i, example in enumerate(ds_slice):
            image = example['image']
            idx = examples_per_class * label_id + i
            box = (idx % examples_per_class * w, idx // examples_per_class * h)
            grid.paste(image.resize(size), box=box)
            draw.text(box, label, (0, 0, 0), font=font)
    
    return grid

# %%
show_grid_of_examples(dataset, seed=42, examples_per_class=3)
# Out:
# Loading cached processed dataset at /Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f/cache-e7f9985801797873.arrow
# Loading cached shuffled indices for dataset at /Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f/cache-c8f4ef71f6854890.arrow
# Loading cached processed dataset at /Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f/cache-bbe6498759d44021.arrow
# Loading cached shuffled indices for dataset at /Users/briandunn/.cache/huggingface/datasets/imagefolder/default-34be8ec909709a38/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f/cache-1d6009d6e0235919.arrow
# <PIL.Image.Image image mode=RGB size=1050x700>

# %% [markdown]
# ##### Remember to Install git lfs & Enter HuggingFace Access Token

# %%
# Enter Huggingface Access Token

# !git lfs install
# Out:
# Git LFS initialized.

# %% [markdown]
# ##### Basic Values/Constants

# %%
MODEL_CKPT='google/vit-base-patch16-224-in21k'
NUM_OF_EPOCHS=3

LEARNING_RATE=2e-4
STEPS=100

BATCH_SIZE=16
DEVICE = torch.device("mps")

REPORTS_TO='tensorboard'

# %% [markdown]
# ##### Load ViT Feature Extractor

# %%
feature_extractor = ViTFeatureExtractor.from_pretrained(MODEL_CKPT)

# %% [markdown]
# ##### Preprocessing Dataset

# %%
def transform(sample_batch):
    # take a list of PIL images and turn them into pixel values
    inputs = feature_extractor([x for x in sample_batch['image']], return_tensors="pt")
    
    # prepare labels
    inputs['labels'] = sample_batch['label']
    return inputs

# %% [markdown]
# ##### Apply Transform Function to Dataset

# %%
prepped_ds = ds.with_transform(transform)

# %% [markdown]
# #### Training & Evaluation

# %% [markdown]
# ##### Define Data Collator

# %%
def data_collator(batch):
    return {
        'pixel_values' : torch.stack([x['pixel_values'] for x in batch]),
        'labels' : torch.tensor([x['labels'] for x in batch])
    }

# %% [markdown]
# ##### Define Evaluation Metric

# %%
def compute_metrics(p):
    accuracy_metric = evaluate.load("accuracy")
    accuracy = accuracy_metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)['accuracy']
    
    ### ------------------- F1 scores -------------------
    
    f1_score_metric = evaluate.load("f1")
    f1_score = f1_score_metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)["f1"]
    
    ### ------------------- recall -------------------
    
    recall_metric = evaluate.load("recall")
    recall = recall_metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)["recall"]
    
    ### ------------------- precision -------------------
    
    precision_metric = evaluate.load("precision")
    precision = precision_metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)["precision"]
    
    return {"accuracy" : accuracy, 
            "F1" : f1_score,
            "Recall" : recall,
            "Precision" : precision,
            }

# %% [markdown]
# ##### Load Pretrained Model

# %%
labels = ds['train'].features['label'].names

model = ViTForImageClassification.from_pretrained(
    MODEL_CKPT,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)}
).to(DEVICE)
# Out:
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ##### Define Training Arguments

# %%
args = TrainingArguments(
    output_dir=MODEL_CKPT + "_male_or_female_eyes",
    remove_unused_columns=False,
    num_train_epochs=NUM_OF_EPOCHS,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=BATCH_SIZE,
    learning_rate=LEARNING_RATE,
    report_to=REPORTS_TO,
    disable_tqdm=False,
    load_best_model_at_end=True,
    logging_first_step=True,
    push_to_hub=True
)

# %% [markdown]
# ##### Instantiate Trainer

# %%
trainer = Trainer(
    model = model,
    args= args,
    data_collator = data_collator,
    compute_metrics = compute_metrics,
    train_dataset=prepped_ds['train'],
    eval_dataset=prepped_ds['test'],
    tokenizer=feature_extractor,
)
# Out:
# /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages/huggingface_hub/repository.py:705: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.11.
#   warnings.warn(
# Cloning https://huggingface.co/DunnBC22/vit-base-patch16-224-in21k_male_or_female_eyes into local empty directory.

# %% [markdown]
# ##### Train Model

# %%
train_results = trainer.train()
# Out:
# /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 9220
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1731
#   Number of trainable parameters = 85800194
# A Jupyter Widget
# {'loss': 0.6902, 'learning_rate': 0.00019988445984979783, 'epoch': 0.0}
# {'loss': 0.1998, 'learning_rate': 0.00014222992489890238, 'epoch': 0.87}
# ***** Running Evaluation *****
#   Num examples = 2305
#   Batch size = 8
# A Jupyter Widget
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-577
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-577/config.json
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-577/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-577/preprocessor_config.json
# {'eval_loss': 0.23654107749462128, 'eval_accuracy': 0.9071583514099784, 'eval_F1': 0.9196093163035313, 'eval_Recall': 0.9975550122249389, 'eval_Precision': 0.8529616724738676, 'eval_runtime': 2023.7125, 'eval_samples_per_second': 1.139, 'eval_steps_per_second': 0.143, 'epoch': 1.0}
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
# {'loss': 0.0846, 'learning_rate': 8.445984979780474e-05, 'epoch': 1.73}
# ***** Running Evaluation *****
#   Num examples = 2305
#   Batch size = 8
# A Jupyter Widget
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1154
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1154/config.json
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1154/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1154/preprocessor_config.json
# {'eval_loss': 0.08100569248199463, 'eval_accuracy': 0.9726681127982646, 'eval_F1': 0.9741273100616017, 'eval_Recall': 0.9665851670741646, 'eval_Precision': 0.9817880794701986, 'eval_runtime': 1994.9085, 'eval_samples_per_second': 1.155, 'eval_steps_per_second': 0.145, 'epoch': 2.0}
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
# {'loss': 0.0309, 'learning_rate': 2.668977469670711e-05, 'epoch': 2.6}
# ***** Running Evaluation *****
#   Num examples = 2305
#   Batch size = 8
# A Jupyter Widget
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1731
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1731/config.json
# {'eval_loss': 0.08515941351652145, 'eval_accuracy': 0.9809110629067245, 'eval_F1': 0.9820992676973149, 'eval_Recall': 0.9837000814995925, 'eval_Precision': 0.9805036555645816, 'eval_runtime': 2062.3394, 'eval_samples_per_second': 1.118, 'eval_steps_per_second': 0.14, 'epoch': 3.0}
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1731/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1731/preprocessor_config.json
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from google/vit-base-patch16-224-in21k_male_or_female_eyes/checkpoint-1154 (score: 0.08100569248199463).
# {'train_runtime': 77859.7741, 'train_samples_per_second': 0.355, 'train_steps_per_second': 0.022, 'train_loss': 0.0932974592238613, 'epoch': 3.0}

# %%
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/config.json
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/config.json
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# A Jupyter Widget
# A Jupyter Widget
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/DunnBC22/vit-base-patch16-224-in21k_male_or_female_eyes
#    3dfd13f..9c58f38  main -> main
#
# To https://huggingface.co/DunnBC22/vit-base-patch16-224-in21k_male_or_female_eyes
#    9c58f38..0e6c7f3  main -> main
# ***** train metrics *****
#   epoch                    =         3.0
#   train_loss               =      0.0933
#   train_runtime            = 21:37:39.77
#   train_samples_per_second =       0.355
#   train_steps_per_second   =       0.022

# %% [markdown]
# ##### Evaluate Model

# %%
metrics = trainer.evaluate(prepped_ds['test'])
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# ***** Running Evaluation *****
#   Num examples = 2305
#   Batch size = 8
# A Jupyter Widget
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_F1                 =     0.9741
#   eval_Precision          =     0.9818
#   eval_Recall             =     0.9666
#   eval_accuracy           =     0.9727
#   eval_loss               =      0.081
#   eval_runtime            = 0:33:40.09
#   eval_samples_per_second =      1.141
#   eval_steps_per_second   =      0.143

# %% [markdown]
# ##### Push Model to Hub (My Profile!)

# %%
kwargs = {
    "finetuned_from" : model.config._name_or_path,
    "tasks" : "image-classification",
    "tags" : ["image-classification"],
}

if args.push_to_hub:
    trainer.push_to_hub("All Dunn!!!")
else:
    trainer.create_model_card(**kwargs)
# Out:
# Saving model checkpoint to google/vit-base-patch16-224-in21k_male_or_female_eyes
# Configuration saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/config.json
# Model weights saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/pytorch_model.bin
# Image processor saved in google/vit-base-patch16-224-in21k_male_or_female_eyes/preprocessor_config.json
# A Jupyter Widget
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/DunnBC22/vit-base-patch16-224-in21k_male_or_female_eyes
#    0e6c7f3..6b73d8b  main -> main
#
# To https://huggingface.co/DunnBC22/vit-base-patch16-224-in21k_male_or_female_eyes
#    6b73d8b..1d9e057  main -> main

# %% [markdown]
# ### Notes & Other Takeaways
# ****
# - The Results were pretty good!
# ****
